# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from pylab import fill_between

# %%
country=pd.read_csv("Country.csv")
indicators=pd.read_csv("Indicators.csv")

# %%
tableau20=["red","blue","yellow","green","orange","purple","brown"]

# %%
indicators.head()
# Out:
#   CountryName CountryCode                                      IndicatorName  \
# 0  Arab World         ARB  Adolescent fertility rate (births per 1,000 wo...
# 1  Arab World         ARB  Age dependency ratio (% of working-age populat...
# 2  Arab World         ARB  Age dependency ratio, old (% of working-age po...
# 3  Arab World         ARB  Age dependency ratio, young (% of working-age ...
# 4  Arab World         ARB        Arms exports (SIPRI trend indicator values)
#
#     IndicatorCode  Year         Value
# 0     SP.ADO.TFRT  1960  1.335609e+02
# 1     SP.POP.DPND  1960  8.779760e+01
# 2  SP.POP.DPND.OL  1960  6.634579e+00
# 3  SP.POP.DPND.YG  1960  8.102333e+01
# 4  MS.MIL.XPRT.KD  1960  3.000000e+06

# %%
indicators.shape
# Out:
# (5656458, 6)

# %%
mask=indicators['CountryName']=="India"
new_Ind=indicators[mask]

# %%
new_Ind
# Out:
#         CountryName CountryCode  \
# 11561         India         IND
# 11562         India         IND
# 11563         India         IND
# 11564         India         IND
# 11565         India         IND
# 11566         India         IND
# 11567         India         IND
# 11568         India         IND
# 11569         India         IND
# 11570         India         IND
# 11571         India         IND
# 11572         India         IND
# 11573         India         IND
# 11574         India         IND
# 11575         India         IND
# 11576         India         IND
# 11577         India         IND
# 11578         India         IND
# 11579         India         IND
# 11580         India         IND
# 11581         India         IND
# 11582         India         IND
# 11583         India         IND
# 11584         India         IND
# 11585         India         IND
# 11586         India         IND
# 11587         India         IND
# 11588         India         IND
# ...

# %%
new_Ind.drop(columns=['CountryCode','IndicatorCode'],inplace=True)

# %%
new_Ind.reset_index(drop=True,inplace=True)

# %% [markdown]
# ### Carbondioxide emission

# %%
#India's
mask=new_Ind['IndicatorName']=="CO2 emissions (kt)"
new_data=new_Ind[mask]

plt.plot(new_data["Year"],new_data["Value"],label="India")


#World's
mask=indicators['IndicatorName']=='CO2 emissions (kt)'
new_data_1=indicators[mask]
arr_decoy=new_data_1.groupby('Year')['Value'].mean()

plt.plot(arr_decoy.index,arr_decoy.values,color="red",label="World")



plt.title("India VS The World")
plt.xlabel("Years")
plt.ylabel("Co2 Emission")
plt.legend(loc=2)

plt.show()

# %%
plt.plot(new_data["Year"],new_data["Value"])
plt.title("India's growth")
# Out:
# Text(0.5, 1.0, "India's growth")

# %%
mask=new_Ind['IndicatorName']=="Life expectancy at birth, total (years)"
new_data=new_Ind[mask]

plt.plot(new_data["Year"],new_data["Value"],label="India")


#World's
mask=indicators['IndicatorName']=='Life expectancy at birth, total (years)'
new_data_1=indicators[mask]
arr_decoy=new_data_1.groupby('Year')['Value'].mean()

plt.plot(arr_decoy.index,arr_decoy.values,color="red",label="World")



plt.title("India VS The World")
plt.xlabel("Years")
plt.ylabel("Life expectancy at birth")
plt.legend(loc=2)


plt.show()

# %%
mask=new_Ind['IndicatorName']=="Population in urban agglomerations of more than 1 million (% of total population)"
new_data=new_Ind[mask]

plt.plot(new_data["Year"],new_data["Value"],label="India")


#World's
mask=indicators['IndicatorName']=='Population in urban agglomerations of more than 1 million (% of total population)'
new_data_1=indicators[mask]
arr_decoy=new_data_1.groupby('Year')['Value'].mean()

plt.plot(arr_decoy.index,arr_decoy.values,color="red",label="World")



plt.title("India VS The World")
plt.xlabel("Years")
plt.ylabel("Population in urban")
plt.legend(loc=2)

plt.show()

# %%
mask=new_Ind['IndicatorName']=="Mortality rate, under-5 (per 1,000)"
new_data=new_Ind[mask]

plt.plot(new_data["Year"],new_data["Value"],label="India")


#World's
mask=indicators['IndicatorName']=='Mortality rate, under-5 (per 1,000)'
new_data_1=indicators[mask]
arr_decoy=new_data_1.groupby('Year')['Value'].mean()

plt.plot(arr_decoy.index,arr_decoy.values,color="red",label="World")



plt.title("India VS The World")
plt.xlabel("Years")
plt.ylabel("Mortality Rate")
plt.legend(loc=2)


plt.show()

# %%
mask=new_Ind['IndicatorName']=="Electric power transmission and distribution losses (% of output)"
new_data=new_Ind[mask]

plt.plot(new_data["Year"],new_data["Value"],label="India")


#World's
mask=indicators['IndicatorName']=='Electric power transmission and distribution losses (% of output)'
new_data_1=indicators[mask]
arr_decoy=new_data_1.groupby('Year')['Value'].mean()

plt.plot(arr_decoy.index,arr_decoy.values,color="red",label="World")



plt.title("India VS The World")
plt.xlabel("Years")
plt.ylabel("Electric power transmission")
plt.legend(loc=2)


plt.show()

# %%
mask=new_Ind['IndicatorName']=="Merchandise exports to high-income economies (% of total merchandise exports)"
new_data=new_Ind[mask]

plt.plot(new_data["Year"],new_data["Value"],label="India")


#World's
mask=indicators['IndicatorName']=='Merchandise exports to high-income economies (% of total merchandise exports)'
new_data_1=indicators[mask]
arr_decoy=new_data_1.groupby('Year')['Value'].mean()

plt.plot(arr_decoy.index,arr_decoy.values,color="red",label="World")



plt.title("India VS The World")
plt.xlabel("Years")
plt.ylabel("Merchantise exports")
plt.legend(loc=2)


plt.show()

# %%
mask=new_Ind['IndicatorName']=="Portfolio equity, net inflows (BoP, current US$)"
new_data=new_Ind[mask]

plt.plot(new_data["Year"],new_data["Value"],label="India")


#World's
mask=indicators['IndicatorName']=='Portfolio equity, net inflows (BoP, current US$)'
new_data_1=indicators[mask]
arr_decoy=new_data_1.groupby('Year')['Value'].mean()

plt.plot(arr_decoy.index,arr_decoy.values,color="red",label="World")



plt.title("External balance on goods and services")
plt.xlabel("Years")
plt.ylabel("")

plt.show()

# %%
mask=new_Ind['IndicatorName']=="Survival to age 65, male (% of cohort)"
new_data=new_Ind[mask]

plt.plot(new_data["Year"],new_data["Value"],label="India")


#World's
mask=indicators['IndicatorName']=='Survival to age 65, male (% of cohort)'
new_data_1=indicators[mask]
arr_decoy=new_data_1.groupby('Year')['Value'].mean()

plt.plot(arr_decoy.index,arr_decoy.values,color="red",label="World")



plt.title("India VS The World")
plt.xlabel("Years")
plt.ylabel("Survival to age 65")
plt.legend(loc=2)


plt.show()

# %%
mask=new_Ind['IndicatorName']=="GDP per capita (current US$)"
new_data=new_Ind[mask]

plt.plot(new_data["Year"],new_data["Value"],label="India")


#World's
mask=indicators['IndicatorName']=='GDP per capita (current US$)'
new_data_1=indicators[mask]
arr_decoy=new_data_1.groupby('Year')['Value'].mean()

plt.plot(arr_decoy.index,arr_decoy.values,color="red",label="World")



plt.title("India VS The World")
plt.xlabel("Years")
plt.ylabel("GDP")
plt.legend(loc=2)


plt.show()

# %%
df_elec_rural = indicators[(indicators.CountryName=='India')&(indicators.IndicatorCode=='EG.ELC.ACCS.RU.ZS')]
df_elec_urban = indicators[(indicators.CountryName=='India')&(indicators.IndicatorCode=='EG.ELC.ACCS.UR.ZS')]
df_elec_pop = indicators[(indicators.CountryName=='India')&(indicators.IndicatorCode=='EG.ELC.ACCS.ZS')]

fig = plt.figure()

plt.plot(df_elec_rural.Year,df_elec_rural.Value,'o-',label='Rural',color="red")
plt.plot(df_elec_urban.Year,df_elec_urban.Value,'o-',label='Urban',color="blue")
plt.plot(df_elec_pop.Year,df_elec_pop.Value,'o-',label='General',color="green")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xlabel('Years',  fontsize=14)
plt.ylabel('% of Population',  fontsize=14)
plt.title('Access to Electricity', fontsize=14)

fig.savefig('access_electricity.pdf',format='pdf', dpi=300)

# %%
df_elec_fosl = indicators[(indicators.CountryName=='India')&(indicators.IndicatorCode=='EG.ELC.FOSL.ZS')]
df_elec_hydro = indicators[(indicators.CountryName=='India')&(indicators.IndicatorCode=='EG.ELC.HYRO.ZS')]
df_elec_nucl = indicators[(indicators.CountryName=='India')&(indicators.IndicatorCode=='EG.ELC.NUCL.ZS')]
df_elec_rnwx = indicators[(indicators.CountryName=='India')&(indicators.IndicatorCode=='EG.ELC.RNWX.ZS')]


fig = plt.figure()

plt.plot(df_elec_fosl.Year,df_elec_fosl.Value,label='Fossil Fuels',color=tableau20[6])
plt.plot(df_elec_hydro.Year,df_elec_hydro.Value,label='Renewable',color=tableau20[0])
plt.plot(df_elec_nucl.Year,df_elec_nucl.Value,label='Nuclear',color=tableau20[3])



fill_between(df_elec_fosl.Year,df_elec_fosl.Value,0,alpha=0.5,color=tableau20[6])
fill_between(df_elec_hydro.Year,df_elec_hydro.Value,0,alpha=0.5,color=tableau20[0])
fill_between(df_elec_nucl.Year,df_elec_nucl.Value,0,alpha=0.5,color=tableau20[3])

#fill_between(x,y2,0,color='magenta')
#fill_between(x,y3,0,color='red')

plt.legend(loc=1, borderaxespad=1.)
plt.xlabel('Years',  fontsize=14)
plt.ylabel('% of Total Energy Produce',  fontsize=14)
plt.title('Energy Mix in the India (1971-2012)', fontsize=18)


fig.savefig('energy_mix.pdf',format='pdf', dpi=300)
